# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd

# %%
base_url = "https://papers.nips.cc"
proc_url = base_url + "/book/advances-in-neural-information-processing-systems-31-2018"

# %%
def get_soup(url):
    page = requests.get(url, timeout=20)
    soup = BeautifulSoup(page.content, "html.parser")
    return soup


def get_contents(a):
    return "".join([str(c) for c in a.contents])


def get_pdf_link(page):
    try:
        return [a for a in paper_page.findAll('a') if a.string == '[PDF]'][0]['href']
    except:
        return None

    
def get_abstract_text(page):
    try:
        return get_contents(paper_page.find("p", {"class": "abstract"}))
    except:
        return None


def get_supplemental_link(page):
    try:
        return [a for a in paper_page.findAll('a') if a.string == '[Supplemental]'][0]['href']
    except:
        return None


def get_event_type(page):
    try:
        return [a for a in page.findAll('h3') if 'Conference Event Type' in a.string][0].string.split(':')[-1]
    except:
        return None


def get_paper_details(paper_page):
    res = {'pdf_link': get_pdf_link(paper_page),
           'abstract_txt': get_abstract_text(paper_page),
           'supplemental_link': get_supplemental_link(paper_page),
           'event_type': get_event_type(paper_page)}
    return res

# %% [markdown]
# ## Download and parse the proceedings paper listing page

# %%
proc_content = get_soup(proc_url)
bullets = proc_content.find_all('li')

# %% [markdown]
# ## Extract high-level metadata for each paper
# - Title
# - Authors
# - Link to paper page

# %%
papers = []
for b in bullets:
    author_divs = b.findAll("a", {"class": "author"})
    paperlinktitle = b.findNext('a')
    res = {'paper_link': paperlinktitle['href'],
           'paper_title': get_contents(paperlinktitle),
           'paper_authors': []}
    for a in author_divs:
        res['paper_authors'].append({'author_name': get_contents(a),
                                    'author_link': a['href']})
    papers.append(res)
papers[-3:]
# Out:
# [{'paper_link': '/paper/8293-transfer-of-deep-reactive-policies-for-mdp-planning',
#   'paper_title': 'Transfer of Deep Reactive Policies for MDP Planning',
#   'paper_authors': [{'author_name': 'Aniket (Nick) Bajpai',
#     'author_link': '/author/aniket-nick-bajpai-12405'},
#    {'author_name': 'Sankalp Garg',
#     'author_link': '/author/sankalp-garg-12406'},
#    {'author_name': 'None', 'author_link': '/author/none-12407'}]},
#  {'paper_link': '/paper/8294-the-price-of-fair-pca-one-extra-dimension',
#   'paper_title': 'The Price of Fair PCA: One Extra dimension',
#   'paper_authors': [{'author_name': 'Samira Samadi',
#     'author_link': '/author/samira-samadi-12408'},
#    {'author_name': 'Uthaipon Tantipongpipat',
#     'author_link': '/author/uthaipon-tantipongpipat-12054'},
#    {'author_name': 'Jamie H. Morgenstern',
#     'author_link': '/author/jamie-h-morgenstern-8075'},
#    {'author_name': 'Mohit Singh', 'author_link': '/author/mohit-singh-12409'},
#    {'author_name': 'Santosh Vempala',
#     'author_link': '/author/santosh-vempala-8164'}]},
#  {'paper_link': '/paper/8295-groupreduce-block-wise-low-rank-approximation-for-neural-language-model-shrinking',
#   'paper_title': 'GroupReduce: Block-Wise Low-Rank Approximation for Neural Language Model Shrinking',
#   'paper_authors': [{'author_name': 'Patrick Chen',
#     'author_link': '/author/patrick-chen-12410'},
#    {'author_name': 'Si Si', 'author_link': '/author/si-si-7479'},
#    {'author_name': 'Yang Li', 'author_link': '/author/yang-li-12411'},
#    {'author_name': 'Ciprian Chelba',
#     'author_link': '/author/ciprian-chelba-12412'},
#    {'author_name': 'Cho-Jui Hsieh',
#     'author_link': '/author/cho-jui-hsieh-6366'}]}]

# %%
print(len(papers))
# Out:
# 1010

# %% [markdown]
# ## Get full metadata for each paper
# - PDF link
# - Supplemental Link
# - Abstract text
# - event type

# %%
for i, paper in enumerate(papers):
    url = paper['paper_link']
    print(i, paper['paper_title'])
    paper_url = base_url + url
    paper_page = get_soup(paper_url)
    paper.update(get_paper_details(paper_page))
# Out:
# 0 Books
# 1 Efficient Algorithms for Non-convex Isotonic Regression through Submodular Optimization
# 2 Structure-Aware Convolutional Neural Networks
# 3 Kalman Normalization: Normalizing Internal Representations Across Network Layers
# 4 HOGWILD!-Gibbs can be PanAccurate
# 5 Text-Adaptive Generative Adversarial Networks: Manipulating Images with Natural Language
# 6 IntroVAE: Introspective Variational Autoencoders for Photographic Image Synthesis
# 7 Doubly Robust Bayesian Inference for Non-Stationary Streaming Data with <var>\beta</var>-Divergences
# 8 Adapted Deep Embeddings: A Synthesis of Methods for k-Shot Inductive Transfer Learning
# 9 Generalized Inverse Optimization through Online Learning
# 10 An Off-policy Policy Gradient Theorem Using Emphatic Weightings
# 11 Supervised autoencoders: Improving generalization performance with unsupervised regularizers
# 12 Visual Object Networks: Image Generation with Disentangled 3D Representations
# 13 Understanding Weight Normalized Deep Neural Networks with Rectified Linear Units
# 14 Learning Pipelines with Limited Data and Domain Knowledge: A Study in Parsing Physics Problems
# 15 Learning long-range spatial dependencies with horizontal gated recurrent units
# 16 Joint Sub-bands Learning with Clique Structures for Wavelet Domain Super-Resolution
# 17 Fast Similarity Search via Optimal Sparse Lifting
# 18 Learning Deep Disentangled Embeddings With the F-Statistic Loss
# 19 Geometrically Coupled Monte Carlo Sampling
# 20 Cooperative Holistic Scene Understanding: Unifying 3D Object, Layout, and Camera Pose Estimation
# 21 An Efficient Pruning Algorithm for Robust Isotonic Regression
# 22 PAC-learning in the presence of adversaries
# 23 Sparse DNNs with Improved Adversarial Robustness
# 24 Snap ML: A Hierarchical Framework for Machine Learning
# 25 See and Think: Disentangling Semantic Scene Completion
# 26 Chain of Reasoning for Visual Question Answering
# 27 Sigsoftmax: Reanalysis of the Softmax Bottleneck
# 28 Deep Non-Blind Deconvolution via Generalized Low-Rank Approximation
# 29 Bayesian Pose Graph Optimization via Bingham Distributions and Tempered Geodesic MCMC
# 30 MetaAnchor: Learning to Detect Objects with Customized Anchors
# 31 Image Inpainting via Generative Multi-column Convolutional Neural Networks
# 32 On Misinformation Containment in Online Social Networks
# 33 A^2-Nets: Double Attention Networks
# 34 Self-Supervised Generation of Spatial Audio for 360° Video
# 35 How Many Samples are Needed to Estimate a Convolutional Neural Network?
# 36 Algorithmic Regularization in Learning Deep Homogeneous Models: Layers are Automatically Balanced
# 37 Optimization for Approximate Submodularity
# 38 (Probably) Concave Graph Matching
# 39 Deep Defense: Training DNNs with Improved Adversarial Robustness
# 40 Rest-Katyusha: Exploiting the Solution's Structure via Scheduled Restart Schemes
# 41 Implicit Reparameterization Gradients
# 42 Training DNNs with Hybrid Block Floating Point
# 43 A Model for Learned Bloom Filters and Optimizing by Sandwiching
# 44 Soft-Gated Warping-GAN for Pose-Guided Person Image Synthesis
# 45 Deep Functional Dictionaries: Learning Consistent Semantic Structures on 3D Models from Functions
# 46 Nonlocal Neural Networks, Nonlocal Diffusion and Nonlocal Modeling
# 47 Are ResNets Provably Better than Linear Predictors?
# 48 Learning to Decompose and Disentangle Representations for Video Prediction
# 49 Multi-Task Learning as Multi-Objective Optimization
# 50 Combinatorial Optimization with Graph Convolutional Networks and Guided Tree Search
# 51 Self-Erasing Network for Integral Object Attention
# 52 LinkNet: Relational Embedding for Scene Graph
# 53 How to Start Training: The Effect of Initialization and Architecture
# 54 Which Neural Net Architectures Give Rise to Exploding and Vanishing Gradients?
# 55 Explanations based on the Missing: Towards Contrastive Explanations with Pertinent Negatives
# 56 HitNet: Hybrid Ternary Recurrent Neural Network
# 57 A Unified Framework for Extensive-Form Game Abstraction with Bounds
# 58 Removing the Feature Correlation Effect of Multiplicative Noise
# 59 Maximum-Entropy Fine Grained Classification
# 60 On Learning Markov Chains
# 61 A Neural Compositional Paradigm for Image Captioning
# 62 Quantifying Learning Guarantees for Convex but Inconsistent Surrogates
# 63 Dialog-based Interactive Image Retrieval
# 64 SPIDER: Near-Optimal Non-Convex Optimization via Stochastic Path-Integrated Differential Estimator
# 65 Are GANs Created Equal? A Large-Scale Study
# 66 Learning Disentangled Joint Continuous and Discrete Representations
# 67 TADAM: Task dependent adaptive metric for improved few-shot learning
# 68 Do Less, Get More: Streaming Submodular Maximization with Subsampling
# 69 Deep Neural Nets with Interpolating Function as Output Activation
# 70 FishNet: A Versatile Backbone for Image, Region, and Pixel Level Prediction
# 71 Visual Memory for Robust Path Following
# 72 KDGAN: Knowledge Distillation with Generative Adversarial Networks
# 73 Long short-term memory and Learning-to-learn in networks of spiking neurons
# 74 Greedy Hash: Towards Fast Optimization for Accurate Hash Coding in CNN
# 75 Informative Features for Model Comparison
# 76 PointCNN: Convolution On X-Transformed Points
# 77 Connectionist Temporal Classification with Maximum Entropy Regularization
# 78 Large Margin Deep Networks for Classification
# 79 Generalizing Graph Matching beyond Quadratic Assignment Model
# 80 Solving Large Sequential Games with the Excessive Gap Technique
# 81 Discrimination-aware Channel Pruning for Deep Neural Networks
# 82 On the Dimensionality of Word Embedding
# 83 Reinforced Continual Learning
# 84 Uncertainty-Aware Attention for Reliable Interpretation and Prediction
# 85 DropMax: Adaptive Variational Softmax
# 86 Posterior Concentration for Sparse Deep Learning
# 87 A flexible model for training action localization with varying levels of supervision
# 88 A Deep Bayesian Policy Reuse Approach Against Non-Stationary Agents
# 89 Empirical Risk Minimization in Non-interactive Local Differential Privacy Revisited
# 90 Low-shot Learning via Covariance-Preserving Adversarial Augmentation Networks
# 91 Learning semantic similarity in a continuous space
# 92 MetaReg: Towards Domain Generalization using Meta-Regularization
# 93 Boosted Sparse and Low-Rank Tensor Regression
# 94 Domain-Invariant Projection Learning for Zero-Shot Recognition
# 95 Neural-Symbolic VQA: Disentangling Reasoning from Vision and Language Understanding
# 96 Frequency-Domain Dynamic Pruning for Convolutional Neural Networks
# 97 Quadratic Decomposable Submodular Function Minimization
# 98 A Block Coordinate Ascent Algorithm for Mean-Variance Optimization
# 99 <var>\ell_1</var>-regression with Heavy-tailed Distributions
# 100 Neural Nearest Neighbors Networks
# 101 Efficient nonmyopic batch active search
# 102 A Game-Theoretic Approach to Recommendation Systems with Strategic Content Providers
# 103 Interactive Structure Learning with Structural Query-by-Committee
# 104 Global Geometry of Multichannel Sparse Blind Deconvolution on the Sphere
# 105 Video-to-Video Synthesis
# 106 How To Make the Gradients Small Stochastically: Even Faster Convex and Nonconvex SGD
# 107 Synthesize Policies for Transfer and Adaptation across Tasks and Environments
# 108 Adversarial vulnerability for any classifier
# 109 Evolution-Guided Policy Gradient in Reinforcement Learning
# 110 Toddler-Inspired Visual Object Learning
# 111 Alternating optimization of decision trees, with application to learning sparse oblique trees
# 112 FD-GAN: Pose-guided Feature Distilling GAN for Robust Person Re-identification
# 113 New Insight into Hybrid Stochastic Gradient Descent: Beyond With-Replacement Sampling and Convexity
# 114 The Lingering of Gradients: How to Reuse Gradients Over Time
# 115 Unsupervised Learning of View-invariant Action Representations
# 116 Fairness Behind a Veil of Ignorance: A Welfare Analysis for Automated Decision Making
# 117 Global Gated Mixture of Second-order Pooling for Improving Deep Convolutional Neural Networks
# 118 Image-to-image translation for cross-domain disentanglement
# 119 Gradient Sparsification for Communication-Efficient Distributed Optimization
# 120 Revisiting Multi-Task Learning with ROCK: a Deep Residual Auxiliary Block for Visual Detection
# 121 Adaptive Online Learning in Dynamic Environments
# 122 FRAGE: Frequency-Agnostic Word Representation
# 123 Generative Neural Machine Translation
# 124 Found Graph Data and Planted Vertex Covers
# 125 Joint Active Feature Acquisition and Classification with Variable-Size Set Encoding
# 126 Regularization Learning Networks: Deep Learning for Tabular Datasets
# 127 Multitask Boosting for Survival Analysis with Competing Risks
# 128 Geometry Based Data Generation
# 129 SLAYER: Spike Layer Error Reassignment in Time
# 130 On Oracle-Efficient PAC RL with Rich Observations
# 131 Gradient Descent for Spiking Neural Networks
# 132 Generalizing Tree Probability Estimation via Bayesian Networks
# 133 Where Do You Think You're Going?: Inferring Beliefs about Dynamics from Behavior
# 134 Designing by Training: Acceleration Neural Network for Fast High-Dimensional Convolution
# 135 Understanding the Role of Adaptivity in Machine Teaching: The Case of Version Space Learners
# 136 A loss framework for calibrated anomaly detection
# 137 PacGAN: The power of two samples in generative adversarial networks
# 138 Variational Memory Encoder-Decoder
# 139 Stochastic Composite Mirror Descent: Optimal Bounds with High Probabilities
# 140 Hybrid Retrieval-Generation Reinforced Agent for Medical Image Report Generation
# 141 Overcoming Language Priors in Visual Question Answering with Adversarial Regularization
# 142 Hybrid Knowledge Routed Modules for Large-scale Object Detection
# 143 Bilinear Attention Networks
# 144 Parsimonious Quantile Regression of Financial Asset Tail Dynamics via Sequential Learning
# 145 Multi-Class Learning: From Theory to Algorithm
# 146 Multivariate Time Series Imputation with Generative Adversarial Networks
# 147 Learning Versatile Filters for Efficient Convolutional Neural Networks
# 148 Accelerated Stochastic Matrix Inversion:  General Theory and  Speeding up BFGS Rules for Faster Second-Order Optimization
# 149 DifNet: Semantic Segmentation by Diffusion Networks
# 150 Conditional Adversarial Domain Adaptation
# 151 Neighbourhood Consensus Networks
# 152 Relating Leverage Scores and Density using Regularized Christoffel Functions
# 153 Non-Local Recurrent Network for Image Restoration
# 154 Bayesian Semi-supervised Learning with Graph Gaussian Processes
# 155 Foreground Clustering for Joint Segmentation and Localization in Videos and Images
# 156 Video Prediction via Selective Sampling
# 157 Distilled Wasserstein Learning for Word Embedding and Topic Modeling
# 158 Learning to Exploit Stability for 3D Scene Parsing
# 159 Neural Guided Constraint Logic Programming for Program Synthesis
# 160 Genetic-Gated Networks for Deep Reinforcement Learning
# 161 Fighting Boredom in Recommender Systems with Linear Reinforcement Learning
# 162 Enhancing the Accuracy and Fairness of Human Decision Making
# 163 Temporal Regularization for Markov Decision Process
# 164 The Pessimistic Limits and Possibilities of Margin-based Losses in Semi-supervised Learning
# 165 Simple random search of static linear policies is competitive for reinforcement learning
# 166 Generating Informative and Diverse Conversational Responses via Adversarial Information Maximization
# 167 Entropy and mutual information in models of deep neural networks
# 168 Collaborative Learning for Deep Neural Networks
# 169 High Dimensional Linear Regression using Lattice Basis Reduction
# 170 Symbolic Graph Reasoning Meets Convolutions
# 171 DVAE#: Discrete Variational Autoencoders with Relaxed Boltzmann Priors
# 172 Partially-Supervised Image Captioning
# 173 3D-Aware Scene Manipulation via Inverse Graphics
# 174 Random Feature Stein Discrepancies
# 175 Distributed Stochastic Optimization via Adaptive SGD
# 176 Precision and Recall for Time Series
# 177 Deep Attentive Tracking via Reciprocative Learning
# 178 Virtual Class Enhanced Discriminative Embedding Learning
# 179 Attention in Convolutional LSTM for Gesture Recognition
# 180 Pelee: A Real-Time Object Detection System on Mobile Devices
# 181 Universal Growth in Production Economies
# 182 Bayesian Model Selection Approach to Boundary Detection with Non-Local Priors
# 183 Efficient Stochastic Gradient Hard Thresholding
# 184 SplineNets: Continuous Neural Decision Graphs
# 185 Generalized Zero-Shot Learning with Deep Calibration Network
# 186 Neural Architecture Search with Bayesian Optimisation and Optimal Transport
# 187 Embedding Logical Queries on Knowledge Graphs
# 188 Learning Optimal Reserve Price against Non-myopic Bidders
# 189 Sequential Context Encoding for Duplicate Removal
# 190 Discovery of Latent 3D Keypoints via End-to-end Geometric Reasoning
# 191 Nonparametric learning from Bayesian models with randomized objective functions
# 192 SEGA: Variance Reduction via Gradient Sketching
# 193 Automatic Program Synthesis of Long Programs with a Learned Garbage Collector
# 194 One-Shot Unsupervised Cross Domain Translation
# 195 Regularizing by the Variance of the Activations' Sample-Variances
# 196 Overlapping Clustering Models, and One (class) SVM to Bind Them All
# 197 Algorithmic Linearly Constrained Gaussian Processes
# 198 DeepExposure: Learning to Expose Photos with Asynchronously Reinforced Adversarial Learning
# 199 Norm matters: efficient and accurate normalization schemes in deep networks
# 200 Dual Principal Component Pursuit: Improved Analysis and Efficient Algorithms
# 201 MULAN: A Blind and Off-Grid Method for Multichannel Echo Retrieval
# 202 Mixture Matrix Completion
# 203 Trajectory Convolution for Action Recognition
# 204 The Description Length of Deep Learning models
# 205 A Smoothed Analysis of the Greedy Algorithm for the Linear Contextual Bandit Problem
# 206 Revisiting Decomposable Submodular Function Minimization with Incidence Relations
# 207 A Practical Algorithm for Distributed Clustering and Outlier Detection
# 208 Learning to Reconstruct Shapes from Unseen Classes
# 209 BourGAN: Generative Networks with Metric Embeddings
# 210 Smoothed analysis of the low-rank approach for smooth semidefinite programs
# 211 Zero-Shot Transfer with Deictic Object-Oriented Representation in Reinforcement Learning
# 212 Overfitting or perfect fitting? Risk bounds for classification and regression rules that interpolate
# 213 Breaking the Span Assumption Yields Fast Finite-Sum Minimization
# 214 Structured Local Minima in Sparse Blind Deconvolution
# 215 GIANT: Globally Improved Approximate Newton Method for Distributed Optimization
# 216 Modelling sparsity, heterogeneity, reciprocity and community structure in temporal interaction data
# 217 Non-monotone Submodular Maximization in Exponentially Fewer Iterations
# 218 MetaGAN: An Adversarial Approach to Few-Shot Learning
# 219 Local Differential Privacy for Evolving Data
# 220 Gaussian Process Conditional Density Estimation
# 221 Meta-Gradient Reinforcement Learning
# 222 Modular Networks: Learning to Decompose Neural Computation
# 223 Learning to Navigate in Cities Without a Map
# 224 Query Complexity of Bayesian Private Learning
# 225 A theory on the absence of spurious solutions for nonconvex and nonsmooth optimization
# 226 Recurrent World Models Facilitate Policy Evolution
# 227 Ridge Regression and Provable Deterministic Ridge Leverage Score Sampling
# 228 Wasserstein Variational Inference
# 229 How Does Batch Normalization Help Optimization?
# 230 Verifiable Reinforcement Learning via Policy Extraction
# 231 Leveraged volume sampling for linear regression
# 232 Model Agnostic Supervised Local Explanations
# 233 A Linear Speedup Analysis of Distributed Deep Learning with Sparse and Quantized Communication
# 234 Active Learning for Non-Parametric Regression Using Purely Random Trees
# 235 Tree-to-tree Neural Networks for Program Translation
# 236 Batch-Instance Normalization for Adaptively Style-Invariant Neural Networks
# 237 Structural Causal Bandits: Where to Intervene?
# 238 Answerer in Questioner's Mind: Information Theoretic Approach to Goal-Oriented Visual Dialog
# 239 A Unified Feature Disentangler for Multi-Domain Image Translation and Manipulation
# 240 Online Learning with an Unknown Fairness Metric
# 241 Isolating Sources of Disentanglement in Variational Autoencoders
# 242 Contextual bandits with surrogate losses: Margin bounds and efficient algorithms
# 243 Representation Learning for Treatment Effect Estimation from Observational Data
# 244 Representation Balancing MDPs for Off-policy Policy Evaluation
# 245 Out of the Box: Reasoning with Graph Convolution Nets for Factual Visual Question Answering
# 246 Causal Discovery from Discrete Data using Hidden Compact Representation
# 247 Natasha 2: Faster Non-Convex Optimization Than SGD
# 248 Minimax Statistical Learning with Wasserstein distances
# 249 Provable Variational Inference for Constrained Log-Submodular Models
# 250 Learning Hierarchical Semantic Image Manipulation through Structured Representations
# 251 Processing of missing data by neural networks
# 252 Safe Active Learning for Time-Series Modeling with Gaussian Processes
# 253 Optimal Algorithms for Non-Smooth Distributed Optimization in Networks
# 254 Computing Higher Order Derivatives of Matrix and Tensor Expressions
# 255 Paraphrasing Complex Network: Network Compression via Factor Transfer
# 256 Analytic solution and stationary phase approximation for the Bayesian lasso and elastic net
# 257 Demystifying excessively volatile human learning: A Bayesian persistent prior and a neural approximation
# 258 Empirical Risk Minimization Under Fairness Constraints
# 259 Unsupervised Learning of Shape and Pose with Differentiable Point Clouds
# 260 Continuous-time Value Function Approximation in Reproducing Kernel Hilbert Spaces
# 261 Gradient Descent Meets Shift-and-Invert Preconditioning for Eigenvector Computation
# 262 Factored Bandits
# 263 Delta-encoder: an effective sample synthesis method for few-shot object recognition
# 264 Metric on Nonlinear Dynamical Systems with Perron-Frobenius Operators
# 265 Learning a High Fidelity Pose Invariant Model for High-resolution Face Frontalization
# 266 Mirrored Langevin Dynamics
# 267 Moonshine: Distilling with Cheap Convolutions
# 268 Stochastic Cubic Regularization for Fast Nonconvex Optimization
# 269 Adaptation to Easy Data in Prediction with Limited Advice
# 270 Differentially Private Bayesian Inference for Exponential Families
# 271 Playing hard exploration games by watching YouTube
# 272 Dialog-to-Action: Conversational Question Answering Over a Large-Scale Knowledge Base
# 273 Norm-Ranging LSH for Maximum Inner Product Search
# 274 Optimization over Continuous and Multi-dimensional Decisions with Observational Data
# 275 Fast Estimation of Causal Interactions using Wold Processes
# 276 When do random forests fail?
# 277 Near Optimal Exploration-Exploitation in Non-Communicating Markov Decision Processes
# 278 Optimistic optimization of a Brownian
# 279 Practical Methods for Graph Two-Sample Testing
# 280 NAIS-Net: Stable Deep Networks from Non-Autonomous  Differential Equations
# 281 On the Global Convergence of Gradient Descent for Over-parameterized Models using Optimal Transport
# 282 Constructing Deep Neural Networks by Bayesian Network Structure Learning
# 283 Weakly Supervised Dense Event Captioning in Videos
# 284 Faithful Inversion of Generative Models for Effective Amortized Inference
# 285 From Stochastic Planning to Marginal MAP
# 286 On Binary Classification in Extreme Regions
# 287 Near-Optimal Policies for Dynamic Multinomial Logit Assortment Selection Models
# 288 Q-learning with Nearest Neighbors
# 289 Global Convergence of Langevin Dynamics Based Algorithms for Nonconvex Optimization
# 290 Asymptotic optimality of adaptive importance sampling
# 291 Learning latent variable structured prediction models with Gaussian perturbations
# 292 The Nearest Neighbor Information Estimator is Adaptively Near Minimax Rate-Optimal
# 293 Deep Reinforcement Learning of Marked Temporal Point Processes
# 294 Evidential Deep Learning to Quantify Classification Uncertainty
# 295 Parsimonious Bayesian deep networks
# 296 Single-Agent Policy Tree Search With Guarantees
# 297 Semi-crowdsourced Clustering with Deep Generative Models
# 298 The committee machine: Computational to statistical gaps in learning a two-layers neural network
# 299 Realistic Evaluation of Deep Semi-Supervised Learning Algorithms
# 300 Contextual Combinatorial Multi-armed Bandits with Volatile Arms and Submodular Reward
# 301 Training deep learning based denoisers without ground truth data
# 302 Re-evaluating evaluation
# 303 Deep, complex, invertible  networks for inversion of transmission effects in multimode optical fibres
# 304 Multivariate Convolutional Sparse Coding for Electromagnetic Brain Signals
# 305 Data-Efficient Hierarchical Reinforcement Learning
# 306 Speaker-Follower Models for Vision-and-Language Navigation
# 307 Inequity aversion improves cooperation in intertemporal social dilemmas
# 308 Learning Gaussian Processes by Minimizing PAC-Bayesian Generalization Bounds
# 309 Probabilistic Matrix Factorization for Automated Machine Learning
# 310 Stochastic Spectral and Conjugate Descent Methods
# 311 Recurrent Relational Networks
# 312 But How Does It Work in Theory? Linear SVM with Random Features
# 313 Learning to Optimize Tensor Programs
# 314 Boosting Black Box Variational Inference
# 315 Nearly tight sample complexity bounds for learning mixtures of Gaussians via sample compression schemes
# 316 Actor-Critic Policy Optimization in Partially Observable Multiagent Environments
# 317 Step Size Matters in Deep Learning
# 318 Derivative Estimation in Random Design
# 319 Zeroth-order (Non)-Convex Stochastic Optimization via Conditional Gradient and Gradient Updates
# 320 Latent Gaussian Activity Propagation: Using Smoothness and Structure to Separate and Localize Sounds in Large Noisy Environments
# 321 Hybrid-MST: A Hybrid Active Sampling Strategy for Pairwise Preference Aggregation
# 322 Infinite-Horizon Gaussian Processes
# 323 Dimensionality Reduction for Stationary Time Series via Stochastic Nonconvex Optimization
# 324 Sequence-to-Segment Networks for Segment Detection
# 325 Scaling the Poisson GLM to massive neural datasets through polynomial approximations
# 326 Multiplicative Weights Updates with Constant Step-Size in Graphical Constant-Sum Games
# 327 Why Is My Classifier Discriminatory?
# 328 Multi-Layered Gradient Boosting Decision Trees
# 329 Learn What Not to Learn: Action Elimination with Deep Reinforcement Learning
# 330 Communication Efficient Parallel Algorithms for Optimization on Manifolds
# 331 Neural Code Comprehension: A Learnable Representation of Code Semantics
# 332 Tight Bounds for Collaborative PAC Learning via Multiplicative Weights
# 333 BinGAN: Learning Compact Binary Descriptors with a Regularized GAN
# 334 Modern Neural Networks Generalize on Small Data Sets
# 335 Escaping Saddle Points in Constrained Optimization
# 336 Adversarial Attacks on Stochastic Bandits
# 337 Optimal Subsampling with Influence Functions
# 338 A Bandit Approach to Sequential Experimental Design with False Discovery Control
# 339 Equality of Opportunity in Classification: A Causal Approach
# 340 Towards Understanding Acceleration Tradeoff between Momentum and Asynchrony in Nonconvex Stochastic Optimization
# 341 Unsupervised Attention-guided Image-to-Image Translation
# 342 Inferring Networks From Random Walk-Based Node Similarities
# 343 NEON2: Finding Local Minima via First-Order Oracles
# 344 Zeroth-Order Stochastic Variance Reduction for Nonconvex Optimization
# 345 Online Structured Laplace Approximations for Overcoming Catastrophic Forgetting
# 346 DeepProbLog:  Neural Probabilistic Logic Programming
# 347 Convergence of Cubic Regularization for Nonconvex Optimization under KL Property
# 348 Direct Estimation of Differences in Causal Graphs
# 349 Sublinear Time Low-Rank Approximation of Distance Matrices
# 350 Variational PDEs for Acceleration on Manifolds and Application to Diffeomorphisms
# 351 Bayesian Inference of Temporal Task Specifications from Demonstrations
# 352 Data center cooling using model-predictive control
# 353 Acceleration through Optimistic No-Regret Dynamics
# 354 Lipschitz regularity of deep neural networks: analysis and efficient estimation
# 355 Minimax Estimation of Neural Net Distance
# 356 Leveraging the Exact Likelihood of Deep Latent Variable Models
# 357 Bipartite Stochastic Block Models with Tiny Clusters
# 358 Learning sparse neural networks via sensitivity-driven regularization
# 359 Faster Online Learning of Optimal Threshold for Consistent F-measure Optimization
# 360 Direct Runge-Kutta Discretization Achieves Acceleration
# 361 Adversarial Examples that Fool both Computer Vision and Time-Limited Humans
# 362 Stochastic Nested Variance Reduced Gradient Descent for Nonconvex Optimization
# 363 Faster Neural Networks Straight from JPEG
# 364 TopRank: A practical algorithm for online stochastic ranking
# 365 Learning from discriminative feature feedback
# 366 RetGK: Graph Kernels based on Return Probabilities of Random Walks
# 367 Deep Generative Markov State Models
# 368 Early Stopping for Nonparametric Testing
# 369 Solving Non-smooth Constrained Programs with Lower Complexity than <var>\mathcal{O}(1/\varepsilon)</var>: A Primal-Dual Homotopy Smoothing Approach
# 370 Heterogeneous Bitwidth Binarization in Convolutional Neural Networks
# 371 Unsupervised Learning of Object Landmarks through Conditional Image Generation
# 372 Probabilistic Neural Programmed Networks for Scene Generation
# 373 The streaming rollout of deep networks - towards fully model-parallel execution
# 374 KONG: Kernels for ordered-neighborhood graphs
# 375 GumBolt: Extending Gumbel trick to Boltzmann priors
# 376 Neural Networks Trained to Solve Differential Equations Learn General Representations
# 377 Beauty-in-averageness and its contextual modulations: A Bayesian statistical account
# 378 Distributed Weight Consolidation: A Brain Segmentation Case Study
# 379 Efficient Projection onto the Perfect Phylogeny Model
# 380 TETRIS: TilE-matching the TRemendous Irregular Sparsity
# 381 Cooperative neural networks (CoNN): Exploiting prior independence structure for improved classification
# 382 Differentially Private Robust Low-Rank Approximation
# 383 Meta-Learning MCMC Proposals
# 384 An Information-Theoretic Analysis for Thompson Sampling with Many Actions
# 385 Flexible and accurate inference and learning for deep generative models
# 386 The Price of Privacy for Low-rank Factorization
# 387 Regret Bounds for Robust Adaptive Control of the Linear Quadratic Regulator
# 388 Bilevel Distance Metric Learning for Robust Image Recognition
# 389 Differentially Private Uniformly Most Powerful Tests for Binomial Data
# 390 Scalable Coordinated Exploration in Concurrent Reinforcement Learning
# 391 Integrated accounts of behavioral and neuroimaging data using flexible recurrent neural network models
# 392 BML: A High-performance, Low-cost Gradient Synchronization Algorithm for DML Training
# 393 Inexact trust-region algorithms on Riemannian manifolds
# 394 Can We Gain More from Orthogonality Regularizations in Training Deep Networks?
# 395 Binary Rating Estimation with Graph Side Information
# 396 SimplE Embedding for Link Prediction in Knowledge Graphs
# 397 Differentially Private Contextual Linear Bandits
# 398 Submodular Field Grammars: Representation, Inference, and Application to Image Parsing
# 399 A Bridging Framework for Model Optimization and Deep Propagation
# 400 Completing State Representations using Spectral Learning
# 401 Optimization of Smooth Functions with Noisy Observations: Local Minimax Rates
# 402 Adding One Neuron Can Eliminate All Bad Local Minima
# 403 Mean-field theory of graph neural networks in graph partitioning
# 404 The Physical Systems Behind Optimization Algorithms
# 405 Mallows Models for Top-k Lists
# 406 Amortized Inference Regularization
# 407 Maximum Causal Tsallis Entropy Imitation Learning
# 408 Limited Memory Kelley's Method Converges for Composite Convex and Submodular Objectives
# 409 Semi-Supervised Learning with Declaratively Specified Entropy Constraints
# 410 End-to-end Symmetry Preserving Inter-atomic Potential Energy Model for Finite and Extended Systems
# 411 Sparsified SGD with Memory
# 412 Exponentiated Strongly Rayleigh Distributions
# 413 Importance Weighting and Variational Inference
# 414 Transfer Learning from Speaker Verification to Multispeaker Text-To-Speech Synthesis
# 415 Expanding Holographic Embeddings for Knowledge Completion
# 416 Lifelong Inverse Reinforcement Learning
# 417 Explaining Deep Learning Models -- A Bayesian Non-parametric Approach
# 418 Third-order Smoothness Helps: Faster Stochastic Optimization Algorithms for Finding Local Minima
# 419 COLA: Decentralized Linear Learning
# 420 MiME: Multilevel Medical Embedding of Electronic Health Records for Predictive Healthcare
# 421 Adaptive Sampling Towards Fast Graph Representation Learning
# 422 Hunting for Discriminatory Proxies in Linear Regression Models
# 423 Towards Robust Detection of Adversarial Examples
# 424 Active Matting
# 425 Learning filter widths of spectral decompositions with wavelets
# 426 Byzantine Stochastic Gradient Descent
# 427 PG-TS: Improved Thompson Sampling for Logistic Contextual Bandits
# 428 Spectral Filtering for General Linear Dynamical Systems
# 429 On Learning Intrinsic Rewards for Policy Gradient Methods
# 430 Boolean Decision Rules via Column Generation
# 431 Adversarial Text Generation via Feature-Mover's Distance
# 432 Fast Rates of ERM and Stochastic Approximation: Adaptive to Error Bound Conditions
# 433 Learning Bounds for Greedy Approximation with Explicit Feature Maps from Multiple Kernels
# 434 A Mathematical Model For Optimal Decisions In A Representative Democracy
# 435 Negotiable Reinforcement Learning for Pareto Optimal Sequential Decision-Making
# 436 Non-metric Similarity Graphs for Maximum Inner Product Search
# 437 Recurrently Controlled Recurrent Networks
# 438 Fast greedy algorithms for dictionary selection with generalized sparsity constraints
# 439 Deep Reinforcement Learning in a Handful of Trials using Probabilistic Dynamics Models
# 440 A Smoother Way to Train Structured Prediction Models
# 441 Context-dependent upper-confidence bounds for directed exploration
# 442 A Unified View of Piecewise Linear Neural Network Verification
# 443 Hierarchical Graph Representation Learning with Differentiable Pooling
# 444 Non-Ergodic Alternating Proximal  Augmented Lagrangian Algorithms with Optimal Rates
# 445 Information-based Adaptive Stimulus Selection to Optimize Communication Efficiency in Brain-Computer Interfaces
# 446 Porcupine Neural Networks: Approximating Neural Network Landscapes
# 447 Fairness Through Computationally-Bounded Awareness
# 448 Adaptive Negative Curvature Descent with Applications in Non-convex Optimization
# 449 Is Q-Learning Provably Efficient?
# 450 Interpreting Neural Network Judgments via Minimal, Stable, and Symbolic Corrections
# 451 Measures of distortion for machine learning
# 452 On the Local Minima of the Empirical Risk
# 453 Densely Connected Attention Propagation for Reading Comprehension
# 454 Bandit Learning with Positive Externalities
# 455 Learning Confidence Sets using Support Vector Machines
# 456 Efficient Neural Network Robustness Certification with General Activation Functions
# 457 Hessian-based Analysis of Large Batch Training and Robustness to Adversaries
# 458 Neural Edit Operations for Biological Sequences
# 459 Objective and efficient inference for couplings in neuronal networks
# 460 Learning from Group Comparisons: Exploiting Higher Order Interactions
# 461 Supervising Unsupervised Learning
# 462 Nonparametric Bayesian Lomax delegate racing for survival analysis with competing risks
# 463 Adversarially Robust Generalization Requires More Data
# 464 Improving Exploration in Evolution Strategies for Deep Reinforcement Learning via a Population of Novelty-Seeking Agents
# 465 Practical exact algorithm for trembling-hand equilibrium refinements in games
# 466 LAG: Lazily Aggregated Gradient for Communication-Efficient Distributed Learning
# 467 Scalable Robust Matrix Factorization with Nonconvex Loss
# 468 Power-law efficient neural codes provide general link between perceptual bias and discriminability
# 469 Geometry-Aware Recurrent Neural Networks for Active Visual Recognition
# 470 Unsupervised Adversarial Invariance
# 471 Content preserving text generation with attribute controls
# 472 Multi-armed Bandits with Compensation
# 473 GradiVeQ: Vector Quantization for Bandwidth-Efficient Gradient Aggregation in Distributed CNN Training
# 474 Learning in Games with Lossy Feedback
# 475 Scalable methods for 8-bit training of neural networks
# 476 Dropping Symmetry for Fast Symmetric Nonnegative Matrix Factorization
# 477 Link Prediction Based on Graph Neural Networks
# 478 Why so gloomy? A Bayesian explanation of human pessimism bias in the multi-armed bandit task
# 479 Near-Optimal Time and Sample Complexities for Solving Markov Decision Processes with a Generative Model
# 480 ChannelNets: Compact and Efficient Convolutional Neural Networks via Channel-Wise Convolutions
# 481 Causal Inference and Mechanism Clustering of A Mixture of Additive Noise Models
# 482 Contour location via entropy reduction leveraging multiple information sources
# 483 Assessing Generative Models via Precision and Recall
# 484 Multiple-Step Greedy Policies in Approximate and Online Reinforcement Learning
# 485 A Convex Duality Framework for GANs
# 486 Horizon-Independent Minimax Linear Regression
# 487 Exploiting Numerical Sparsity for Efficient Learning : Faster Eigenvector Computation and Regression
# 488 Experimental Design for Cost-Aware Learning of Causal Graphs
# 489 Task-Driven Convolutional Recurrent Models of the Visual System
# 490 Meta-Reinforcement Learning of Structured Exploration Strategies
# 491 Sample Efficient Stochastic Gradient Iterative Hard Thresholding Method for Stochastic Sparse Linear Regression with Limited Attribute Observation
# 492 Semi-supervised Deep Kernel Learning: Regression with Unlabeled Data by Minimizing Predictive Variance
# 493 Generalizing to Unseen Domains via Adversarial Data Augmentation
# 494 Hyperbolic Neural Networks
# 495 Breaking the Curse of Horizon: Infinite-Horizon Off-Policy Estimation
# 496 Learning Task Specifications from Demonstrations
# 497 Learning a latent manifold of odor representations from neural responses in piriform cortex
# 498 Fully Understanding The Hashing Trick
# 499 Evolved Policy Gradients
# 500 The Spectrum of the Fisher Information Matrix of a Single-Hidden-Layer Neural Network
# 501 Learning Concave Conditional Likelihood Models for Improved Analysis of Tandem Mass Spectra
# 502 Differentially Private k-Means with Constant Multiplicative Error
# 503 Policy Optimization via Importance Sampling
# 504 Estimating Learnability in the Sublinear Data Regime
# 505 Algorithmic Assurance: An Active Approach to Algorithmic Testing using Bayesian Optimisation
# 506 Community Exploration: From Offline Optimization to Online Learning
# 507 A Dual Framework for Low-rank Tensor Completion
# 508 Low-rank Interaction with Sparse Additive Effects Model for Large Data Frames
# 509 Inference Aided Reinforcement Learning for Incentive Mechanism Design in Crowdsourcing
# 510 Middle-Out Decoding
# 511 First-order Stochastic Algorithms for Escaping From Saddle Points in Almost Linear Time
# 512 To Trust Or Not To Trust A Classifier
# 513 Reparameterization Gradient for Non-differentiable Models
# 514 A Simple Proximal Stochastic Gradient Method for Nonsmooth Nonconvex Optimization
# 515 Multimodal Generative Models for Scalable Weakly-Supervised Learning
# 516 How Much Restricted Isometry is Needed In Nonconvex Matrix Recovery?
# 517 Occam's razor is insufficient to infer the preferences of irrational agents
# 518 Manifold Structured Prediction
# 519 Fast Greedy MAP Inference for Determinantal Point Process to Improve Recommendation Diversity
# 520 Learning Others' Intentional Models in Multi-Agent Settings Using Interactive POMDPs
# 521 Contextual Pricing for Lipschitz Buyers
# 522 Online Improper Learning with an Approximation Oracle
# 523 Bandit Learning in Concave N-Person Games
# 524 On Fast Leverage Score Sampling and Optimal Learning
# 525 Unsupervised Video Object Segmentation for Deep Reinforcement Learning
# 526 Efficient inference for time-varying behavior during learning
# 527 Learning convex polytopes with margin
# 528 Critical initialisation for deep signal propagation in noisy rectifier neural networks
# 529 Insights on representational similarity in neural networks with canonical correlation
# 530 Variational Inference with Tail-adaptive f-Divergence
# 531 Mental Sampling in Multimodal Representations
# 532 Adversarially Robust Optimization with Gaussian Processes
# 533 Learning to Multitask
# 534 Loss Functions for Multiset Prediction
# 535 Computing Kantorovich-Wasserstein Distances on <var>d</var>-dimensional histograms using <var>(d+1)</var>-partite graphs
# 536 Neural Interaction Transparency (NIT): Disentangling Learned Interactions for Improved Interpretability
# 537 CapProNet: Deep Feature Learning via Orthogonal Projections onto Capsule Subspaces
# 538 Gamma-Poisson Dynamic Matrix Factorization Embedded with Metadata Influence
# 539 Masking: A New Perspective of Noisy Supervision
# 540 On GANs and GMMs
# 541 Differential Properties of Sinkhorn Approximation for Learning with Wasserstein Distance
# 542 Practical Deep Stereo (PDS): Toward applications-friendly deep stereo matching
# 543 A Bayes-Sard Cubature Method
# 544 Dual Swap Disentangling
# 545 Diverse Ensemble Evolution: Curriculum Data-Model Marriage
# 546 Binary Classification from Positive-Confidence Data
# 547 Deep Generative Models for Distribution-Preserving Lossy Compression
# 548 Exact natural gradient in deep linear networks and its application to the nonlinear case
# 549 Constructing Fast Network through Deconstruction of Convolution
# 550 Memory Replay GANs: Learning to Generate New Categories without Forgetting
# 551 The Convergence of Sparsified Gradient Methods
# 552 Automating Bayesian optimization with Bayesian optimization
# 553 Stacked Semantics-Guided Attention Model for Fine-Grained Zero-Shot Learning
# 554 Dirichlet-based Gaussian Processes for Large-scale Calibrated Classification
# 555 Multi-Task Zipping via Layer-wise Neuron Sharing
# 556 Dimensionally Tight Bounds for Second-Order Hamiltonian Monte Carlo
# 557 Approximation algorithms for stochastic clustering
# 558 Evolutionary Stochastic Gradient Descent for Optimization of Deep Neural Networks
# 559 Learning to Infer Graphics Programs from Hand-Drawn Images
# 560 Graphical Generative Adversarial Networks
# 561 Variational Learning on Aggregate Outputs with Gaussian Processes
# 562 MacNet: Transferring Knowledge from Machine Comprehension to Sequence-to-Sequence Models
# 563 Poison Frogs! Targeted Clean-Label Poisoning Attacks on Neural Networks
# 564 Information Constraints on Auto-Encoding Variational Bayes
# 565 Recurrent Transformer Networks for Semantic Correspondence
# 566 Online convex optimization for cumulative constraints
# 567 Predict Responsibly: Improving Fairness and Accuracy by Learning to Defer
# 568 Deep State Space Models for Unconditional Word Generation
# 569 ResNet with one-neuron hidden layers is a Universal Approximator
# 570 Transfer of Value Functions via Variational Methods
# 571 The Cluster Description Problem - Complexity Results, Formulations and Approximations
# 572 Sharp Bounds for Generalized Uniformity Testing
# 573 Deep Neural Networks with Box Convolutions
# 574 Learning towards Minimum Hyperspherical Energy
# 575 LF-Net: Learning Local Features from Images
# 576 SLANG: Fast Structured Covariance Approximations for Bayesian Deep Learning with Natural Gradient
# 577 Tangent: Automatic differentiation using source-code transformation for dynamically typed array programming
# 578 Multi-domain Causal Structure Learning in Linear Systems
# 579 Privacy Amplification by Subsampling: Tight Analyses via Couplings and Divergences
# 580 Exponentially Weighted Imitation Learning for Batched Historical Data
# 581 Algebraic tests of general Gaussian latent tree models
# 582 Navigating with Graph Representations for Fast and Scalable Decoding of Neural Language Models
# 583 Deep Structured Prediction with Nonlinear Output Transformations
# 584 Sequential Test for the Lowest Mean: From Thompson to Murphy Sampling
# 585 Distributed Learning without Distress: Privacy-Preserving Empirical Risk Minimization
# 586 A no-regret generalization of hierarchical softmax to extreme multi-label classification
# 587 Efficient Formal Safety Analysis of Neural Networks
# 588 Bayesian Distributed Stochastic Gradient Descent
# 589 Visualizing the Loss Landscape of Neural Nets
# 590 The Limits of Post-Selection Generalization
# 591 Graph Convolutional Policy Network for Goal-Directed Molecular Graph Generation
# 592 On Controllable Sparse Alternatives to Softmax
# 593 L4: Practical loss-based stepsize adaptation for deep learning
# 594 Learning Latent Subspaces in Variational Autoencoders
# 595 Turbo Learning for CaptionBot and DrawingBot
# 596 Learning to Teach with Dynamic Loss Functions
# 597 Multi-View Silhouette and Depth Decomposition for High Resolution 3D Object Representation
# 598 Size-Noise Tradeoffs in Generative Networks
# 599 Online Adaptive Methods, Universality and Acceleration
# 600 Compact Generalized Non-local Network
# 601 On the Local Hessian in Back-propagation
# 602 The Everlasting Database: Statistical Validity at a Fair Price
# 603 Lipschitz-Margin Training: Scalable Certification of Perturbation Invariance for Deep Neural Networks
# 604 Proximal SCOPE for Distributed Sparse Learning
# 605 On Coresets for Logistic Regression
# 606 Neural Ordinary Differential Equations
# 607 Unsupervised Learning of Artistic Styles with Archetypal Style Analysis
# 608 Approximating Real-Time Recurrent Learning with Random Kronecker Factors
# 609 Contamination Attacks and Mitigation in Multi-Party Machine Learning
# 610 An Improved Analysis of Alternating Minimization for Structured Multi-Response Regression
# 611 Incorporating Context into Language Encoding Models for fMRI
# 612 CatBoost: unbiased boosting with categorical features
# 613 Query K-means Clustering and the Double Dixie Cup Problem
# 614 Training Neural Networks Using Features Replay
# 615 Modeling Dynamic Missingness of Implicit Feedback for Recommendation
# 616 Representation Learning of Compositional Data
# 617 Model-based targeted dimensionality reduction for neuronal population data
# 618 On gradient regularizers for MMD GANs
# 619 Heterogeneous Multi-output Gaussian Process Prediction
# 620 Large-Scale Stochastic Sampling from the Probability Simplex
# 621 Policy Regret in Repeated Games
# 622 A Theory-Based Evaluation of Nearest Neighbor Models Put Into Practice
# 623 Banach Wasserstein GAN
# 624 Provable Gaussian Embedding with One Observation
# 625 BRITS: Bidirectional Recurrent Imputation for Time Series
# 626 M-Walk: Learning to Walk over Graphs using Monte Carlo Tree Search
# 627 Extracting Relationships by Multi-Domain Matching
# 628 Efficient Gradient Computation for Structured Output Learning with Rational and Tropical Losses
# 629 Generative Probabilistic Novelty Detection with Adversarial Autoencoders
# 630 Diminishing Returns Shape Constraints for Interpretability and Regularization
# 631 Scalable Hyperparameter Transfer Learning
# 632 Stochastic Nonparametric Event-Tensor Decomposition
# 633 Scaling Gaussian Process Regression with Derivatives
# 634 Differentially Private Testing of Identity and Closeness of Discrete Distributions
# 635 Bayesian Adversarial Learning
# 636 Efficient Convex Completion of Coupled Tensors using Coupled Nuclear Norms
# 637 Maximizing Induced Cardinality Under a Determinantal Point Process
# 638 Causal Inference with Noisy and Missing Covariates via Matrix Factorization
# 639 rho-POMDPs have Lipschitz-Continuous epsilon-Optimal Value Functions
# 640 Online Structure Learning for Feed-Forward and Recurrent Sum-Product Networks
# 641 Uncertainty Sampling is Preconditioned Stochastic Gradient Descent on Zero-One Loss
# 642 A Probabilistic U-Net for Segmentation of Ambiguous Images
# 643 Unorganized Malicious Attacks Detection
# 644 Causal Inference via Kernel Deviance Measures
# 645 Bayesian Alignments of Warped Multi-Output Gaussian Processes
# 646 Hybrid Macro/Micro Level Backpropagation for Training Deep Spiking Neural Networks
# 647 Gen-Oja: Simple & Efficient Algorithm for Streaming Generalized Eigenvector Computation
# 648 Efficient online algorithms for fast-rate regret bounds under sparsity
# 649 GILBO: One Metric to Measure Them All
# 650 Predictive Uncertainty Estimation via Prior Networks
# 651 Dual Policy Iteration
# 652 A probabilistic population code based on neural samples
# 653 Manifold-tiling Localized Receptive Fields are Optimal in Similarity-preserving Neural Networks
# 654 On the Convergence and Robustness of Training GANs with Regularized Optimal Transport
# 655 Model-Agnostic Private Learning
# 656 Constrained Generation of Semantically Valid Graphs via Regularizing Variational Autoencoders
# 657 Provably Correct Automatic Sub-Differentiation for Qualified Programs
# 658 Deep Homogeneous Mixture Models: Representation, Separation, and Approximation
# 659 Parameters as interacting particles: long time convergence and asymptotic error scaling of neural networks
# 660 Hierarchical Reinforcement Learning for Zero-shot Generalization with Subtask Dependencies
# 661 A Simple Unified Framework for Detecting Out-of-Distribution Samples and Adversarial Attacks
# 662 End-to-End Differentiable Physics for Learning and Control
# 663 BRUNO: A Deep Recurrent Model for Exchangeable Data
# 664 Stimulus domain transfer in recurrent models for large scale cortical population prediction on video
# 665 Mapping Images to Scene Graphs with Permutation-Invariant Structured Prediction
# 666 Distributed Multi-Player Bandits - a Game of Thrones Approach
# 667 Efficient Loss-Based Decoding on Graphs for Extreme Classification
# 668 Chaining Mutual Information and Tightening Generalization Bounds
# 669 Implicit Probabilistic Integrators for ODEs
# 670 Learning Attentional Communication for Multi-Agent Cooperation
# 671 Training Deep Models Faster with Robust, Approximate Importance Sampling
# 672 Bandit Learning with Implicit Feedback
# 673 Unsupervised Text Style Transfer using Language Models as Discriminators
# 674 Relational recurrent neural networks
# 675 Streaming Kernel PCA with <var>\tilde{O}(\sqrt{n})</var> Random Features
# 676 REFUEL: Exploring Sparse Features in Deep Reinforcement Learning for Fast Disease Diagnosis
# 677 Bayesian Model-Agnostic Meta-Learning
# 678 Disconnected Manifold Learning for Generative Adversarial Networks
# 679 Unsupervised Cross-Modal Alignment of Speech and Text Embedding Spaces
# 680 Learning Signed Determinantal Point Processes through the Principal Minor Assignment Problem
# 681 Out-of-Distribution Detection using Multiple Semantic Label Representations
# 682 Stochastic Chebyshev Gradient Descent for Spectral Optimization
# 683 Revisiting <var>(\epsilon, \gamma, \tau)</var>-similarity learning for domain adaptation
# 684 How to tell when a clustering is (approximately) correct using convex relaxations
# 685 Constant Regret, Generalized Mixability, and Mirror Descent
# 686 A Bayesian Approach to Generative Adversarial Imitation Learning
# 687 Plug-in Estimation in High-Dimensional Linear Inverse Problems: A Rigorous Analysis
# 688 Constrained Cross-Entropy Method for Safe Reinforcement Learning
# 689 Multi-Agent Generative Adversarial Imitation Learning
# 690 Adaptive Learning with Unknown Information Flows
# 691 Forecasting Treatment Responses Over Time Using Recurrent Marginal Structural Networks
# 692 Generative modeling for protein structures
# 693 Inference in Deep Gaussian Processes using Stochastic Gradient Hamiltonian Monte Carlo
# 694 Knowledge Distillation by On-the-Fly Native Ensemble
# 695 Non-Adversarial Mapping with VAEs
# 696 Generalisation in humans and deep neural networks
# 697 Towards Text Generation with Adversarially Learned Neural Outlines
# 698 cpSGD: Communication-efficient and differentially-private distributed SGD
# 699 GPyTorch: Blackbox Matrix-Matrix Gaussian Process Inference with GPU Acceleration
# 700 Diffusion Maps for Textual Network Embedding
# 701 Simple, Distributed, and Accelerated Probabilistic Programming
# 702 VideoCapsuleNet: A Simplified Network for Action Detection
# 703 Rectangular Bounding Process
# 704 Improved Algorithms for Collaborative PAC Learning
# ...
# 774 Scaling provable adversarial defenses
# 775 Deep Network for the Integrated 3D Sensing of Multiple People in Natural Images
# 776 Almost Optimal Algorithms for Linear Stochastic Bandits with Heavy-Tailed Payoffs
# 777 Data-dependent PAC-Bayes priors via differential privacy
# 778 Deep Poisson gamma dynamical systems
# 779 Dimensionality Reduction has Quantifiable Imperfections: Two Geometric Bounds
# 780 Teaching Inverse Reinforcement Learners via Features and Demonstrations
# 781 Wasserstein Distributionally Robust Kalman Filtering
# 782 Generalisation of structural knowledge in the hippocampal-entorhinal system
# 783 Graph Oracle Models, Lower Bounds, and Gaps for Parallel Stochastic Optimization
# 784 Adversarial Regularizers in Inverse Problems
# 785 Clustering Redemption–Beyond the Impossibility of Kleinberg’s Axioms
# 786 Co-teaching: Robust training of deep neural networks with extremely noisy labels
# 787 Variational Inverse Control with Events: A General Framework for Data-Driven Reward Definition
# 788 A convex program for bilinear inversion of sparse vectors
# 789 Adversarial Multiple Source Domain Adaptation
# 790 Neural Tangent Kernel: Convergence and Generalization in Neural Networks
# 791 Contextual Stochastic Block Models
# 792 A Likelihood-Free Inference Framework for Population Genetic Data using Exchangeable Neural Networks
# 793 Sequential Attend, Infer, Repeat: Generative Modelling of Moving Objects
# 794 Randomized Prior Functions for Deep Reinforcement Learning
# 795 Compact Representation of Uncertainty in Clustering
# 796 Learning without the Phase: Regularized PhaseMax Achieves Optimal Sample Complexity
# 797 Multilingual Anchoring: Interactive Topic Modeling and Alignment Across Languages
# 798 Estimators for Multivariate Information Measures in General Probability Spaces
# 799 DeepPINK: reproducible feature selection in deep neural networks
# 800 HOUDINI: Lifelong Learning as Program Synthesis
# 801 Searching for Efficient Multi-Scale Architectures for Dense Image Prediction
# 802 Orthogonally Decoupled Variational Gaussian Processes
# 803 Dendritic cortical microcircuits approximate the backpropagation algorithm
# 804 Learning Plannable Representations with Causal InfoGAN
# 805 Uniform Convergence of Gradients for Non-Convex Learning and Optimization
# 806 Automatic differentiation in ML: Where we are and where we should be going
# 807 A Bayesian Nonparametric View on Count-Min Sketch
# 808 Generalized Cross Entropy Loss for Training Deep Neural Networks with Noisy Labels
# 809 Loss Surfaces, Mode Connectivity, and Fast Ensembling of DNNs
# 810 Flexible neural representation for physics prediction
# 811 Legendre Decomposition for Tensors
# 812 Reinforcement Learning of Theorem Proving
# 813 Data Amplification: A Unified and Competitive Approach to Property Estimation
# 814 Group Equivariant Capsule Networks
# 815 Stein Variational Gradient Descent as Moment Matching
# 816 Differential Privacy for Growing Databases
# 817 Exploration in Structured Reinforcement Learning
# 818 A Statistical Recurrent Model on the Manifold of Symmetric Positive Definite Matrices
# 819 Balanced Policy Evaluation and Learning
# 820 Distributed Multitask Reinforcement Learning with Quadratic Convergence
# 821 Improving Neural Program Synthesis with Inferred Execution Traces
# 822 Adaptive Path-Integral Autoencoders: Representation Learning and Planning for Dynamical Systems
# 823 Policy-Conditioned Uncertainty Sets for Robust Markov Decision Processes
# 824 GLoMo: Unsupervised Learning of Transferable Relational Graphs
# 825 Online Learning of Quantum States
# 826 Wavelet regression and additive models for irregularly spaced data
# 827 Inferring Latent Velocities from Weather Radar Data using Gaussian Processes
# 828 A Structured Prediction Approach for Label Ranking
# 829 Efficient High Dimensional Bayesian Optimization with Additivity and Quadrature Fourier Features
# 830 FastGRNN: A Fast, Accurate, Stable and Tiny Kilobyte Sized Gated Recurrent Neural Network
# 831 Reversible Recurrent Neural Networks
# 832 SING: Symbol-to-Instrument Neural Generator
# 833 Learning Compressed Transforms with Low Displacement Rank
# 834 Theoretical Linear Convergence of Unfolded ISTA and Its Practical Weights and Thresholds
# 835 Iterative Value-Aware Model Learning
# 836 Invariant Representations without Adversarial Training
# 837 Robot Learning in Homes: Improving Generalization and Reducing Dataset Bias
# 838 Learning Safe Policies with Expert Guidance
# 839 Bayesian multi-domain learning for cancer subtype discovery from next-generation sequencing count data
# 840 Learning SMaLL Predictors
# 841 Phase Retrieval Under a Generative Prior
# 842 Quadrature-based features for kernel approximation
# 843 Reducing Network Agnostophobia
# 844 A Stein variational Newton method
# 845 Watch Your Step: Learning Node Embeddings via Graph Attention
# 846 Visual Reinforcement Learning with Imagined Goals
# 847 Deep Predictive Coding Network with Local Recurrent Processing for Object Recognition
# 848 PAC-Bayes bounds for stable algorithms with instance-dependent priors
# 849 Beyond Grids: Learning Graph Representations for Visual Recognition
# 850 The Limit Points of (Optimistic) Gradient Descent in Min-Max Optimization
# 851 Coordinate Descent with Bandit Sampling
# 852 Deep Dynamical Modeling and Control of Unsteady Fluid Flows
# 853 Confounding-Robust Policy Improvement
# 854 The Importance of Sampling inMeta-Reinforcement Learning
# 855 Representer Point Selection for Explaining Deep Neural Networks
# 856 The Effect of Network Width on the Performance of  Large-batch Training
# 857 SNIPER: Efficient Multi-Scale Training
# 858 The Sample Complexity of Semi-Supervised Learning with Nonparametric Mixture Models
# 859 Hardware Conditioned Policies for Multi-Robot Transfer Learning
# 860 Co-regularized Alignment for Unsupervised Domain Adaptation
# 861 Statistical and Computational Trade-Offs in Kernel K-Means
# 862 Assessing the Scalability of Biologically-Motivated Deep Learning Algorithms and Architectures
# 863 Learning Attractor Dynamics for Generative Memory
# 864 The emergence of multiple retinal cell types through efficient coding of natural movies
# 865 Gather-Excite: Exploiting Feature Context in Convolutional Neural Networks
# 866 The Global Anchor Method for Quantifying Linguistic Shifts and Domain Adaptation
# 867 Identification and Estimation of Causal Effects from Dependent Data
# 868 Deepcode: Feedback Codes via Deep Learning
# 869 Learning and Testing Causal Models with Interventions
# 870 Implicit Bias of Gradient Descent on Linear Convolutional Networks
# 871 DAGs with NO TEARS: Continuous Optimization for Structure Learning
# 872 PAC-Bayes Tree: weighted subtrees with guarantees
# 873 Multi-objective Maximization of Monotone Submodular Functions with Cardinality Constraint
# 874 Sanity Checks for Saliency Maps
# 875 Probabilistic Model-Agnostic Meta-Learning
# 876 Reinforcement Learning with Multiple Experts: A Bayesian Model Combination Approach
# 877 e-SNLI: Natural Language Inference with Natural Language Explanations
# 878 Fast Approximate Natural Gradient Descent in a Kronecker Factored Eigenbasis
# 879 Learning convex bounds for linear quadratic control policy synthesis
# 880 Neural Proximal Gradient Descent for Compressive Imaging
# 881 Towards Understanding Learning Representations: To What Extent Do Different Neural Networks Learn the Same Representation
# 882 Optimal Algorithms for Continuous Non-monotone Submodular and DR-Submodular Maximization
# 883 An intriguing failing of convolutional neural networks and the CoordConv solution
# 884 Trading robust representations for sample complexity through self-supervised visual experience
# 885 Invertibility of Convolutional Generative Networks from Partial Measurements
# 886 Ex ante coordination and collusion in zero-sum multi-player extensive-form games
# 887 Multi-Agent Reinforcement Learning via Double Averaging Primal-Dual Optimization
# 888 Improving Online Algorithms via ML Predictions
# 889 Global Non-convex Optimization with Discretized Diffusions
# 890 Theoretical guarantees for EM under misspecified Gaussian mixture models
# 891 Coupled Variational Bayes via Optimization Embedding
# 892 Improving Explorability in Variational Inference with Annealed Variational Objectives
# 893 Latent Alignment and Variational Attention
# 894 Towards Deep Conversational Recommendations
# 895 Unsupervised Depth Estimation, 3D Face Rotation and Replacement
# 896 Generalization Bounds for Uniformly Stable Algorithms
# 897 Deep Anomaly Detection Using Geometric Transformations
# 898 Large Scale computation of Means and Clusters for Persistence Diagrams using Optimal Transport
# 899 Entropy Rate Estimation for Markov Chains with Large State Space
# 900 Adaptive Methods for Nonconvex Optimization
# 901 Object-Oriented Dynamics Predictor
# 902 Adaptive Skip Intervals: Temporal Abstraction for Recurrent Dynamical Models
# 903 Scalable End-to-End Autonomous Vehicle Testing via Rare-event Simulation
# 904 Reinforcement Learning for Solving the Vehicle Routing Problem
# 905 ATOMO: Communication-efficient Learning via Atomic Sparsification
# 906 Dynamic Network Model from Partial Observations
# 907 Life-Long Disentangled Representation Learning with Cross-Domain Latent Homologies
# 908 Maximizing acquisition functions for Bayesian optimization
# 909 On Markov Chain Gradient Descent
# 910 Variance-Reduced Stochastic Gradient Descent on Streaming Data
# 911 Online Robust Policy Learning in the Presence of Unknown Adversaries
# 912 Uplift Modeling from Separate Labels
# 913 Learning Invariances using the Marginal Likelihood
# 914 Non-delusional Q-learning and value-iteration
# 915 Using Large Ensembles of Control Variates for Variational Inference
# 916 Post: Device Placement with Cross-Entropy Minimization and Proximal Policy Optimization
# 917 Learning to Reason with Third Order Tensor Products
# 918 Memory Augmented Policy Optimization for Program Synthesis and Semantic Parsing
# 919 Persistence Fisher Kernel: A Riemannian Manifold Kernel for Persistence Diagrams
# 920 Neural Voice Cloning with a Few Samples
# 921 Blind Deconvolutional Phase Retrieval via Convex Programming
# 922 Scalable Laplacian K-modes
# 923 A Retrieve-and-Edit Framework for Predicting Structured Outputs
# 924 Testing for Families of Distributions via the Fourier Transform
# 925 Thwarting Adversarial Examples: An <var>L_0</var>-Robust Sparse Fourier Transform
# 926 Blockwise Parallel Decoding for Deep Autoregressive Models
# 927 Low-Rank Tucker Decomposition of Large Tensors Using TensorSketch
# 928 A Simple Cache Model for Image Recognition
# 929 Clebsch–Gordan Nets: a Fully Fourier Space Spherical Convolutional Neural Network
# 930 Bayesian Nonparametric Spectral Estimation
# 931 A Spectral View of Adversarially Robust Features
# 932 Synaptic Strength For Convolutional Neural Network
# 933 Human-in-the-Loop Interpretability Prior
# 934 Learning To Learn Around A Common Mean
# 935 Backpropagation with Callbacks: Foundations for Efficient and Expressive Differentiable Programming
# 936 Learning with SGD and Random Features
# 937 Total stochastic gradient algorithms and applications in reinforcement learning
# 938 Glow: Generative Flow with Invertible 1x1 Convolutions
# 939 Nonparametric Density Estimation under Adversarial Losses
# 940 Generalizing Point Embeddings using the Wasserstein Space of Elliptical Distributions
# 941 Learning to Share and Hide Intentions using Information Regularization
# 942 Predictive Approximate Bayesian Computation via Saddle Points
# 943 Robustness of conditional GANs to noisy labels
# 944 Robust Learning of Fixed-Structure Bayesian Networks
# 945 Improving Simple Models with Confidence Profiles
# 946 PCA of high dimensional random walks with comparison to neural network training
# 947 Learning to Solve SMT Formulas
# 948 Lifted Weighted Mini-Bucket
# 949 Learning and Inference in Hilbert Space with Quantum Graphical Models
# 950 Unsupervised Image-to-Image Translation Using Domain-Specific Variational Information Bound
# 951 Adversarial Risk and Robustness: General Definitions and Implications for the Uniform Distribution
# 952 Gaussian Process Prior Variational Autoencoders
# 953 3D Steerable CNNs: Learning Rotationally Equivariant Features in Volumetric Data
# 954 Context-aware Synthesis and Placement of Object Instances
# 955 Convex Elicitation of Continuous Properties
# 956 Mesh-TensorFlow: Deep Learning for Supercomputers
# 957 Learning Abstract Options
# 958 Bounded-Loss Private Prediction Markets
# 959 Temporal alignment and latent Gaussian process factor inference in population spike trains
# 960 Using Trusted Data to Train Deep Networks on Labels Corrupted by Severe Noise
# 961 Discretely Relaxing Continuous Variables for tractable Variational Inference
# 962 Regret bounds for meta Bayesian optimization with an unknown Gaussian process prior
# 963 Diversity-Driven Exploration Strategy for Deep Reinforcement Learning
# 964 Deep Generative Models with Learnable Knowledge Constraints
# 965 The Sparse Manifold Transform
# 966 Bayesian Structure Learning by Recursive Bootstrap
# 967 Complex Gated Recurrent Neural Networks
# 968 Learning a Warping Distance from Unlabeled Time Series Using Sequence Autoencoders
# 969 Streamlining Variational Inference for Constraint Satisfaction Problems
# 970 Fast deep reinforcement learning using online adjustments from the past
# 971 Improved Network Robustness with Adversary Critic
# 972 Regret Bounds for Online Portfolio Selection with a Cardinality Constraint
# 973 Sketching Method for Large Scale Combinatorial Inference
# 974 Connecting Optimization and Regularization Paths
# 975 Fully Neural Network Based Speech Recognition on Mobile and Embedded Devices
# 976 Understanding Regularized Spectral Clustering via Graph Conductance
# 977 Data-Driven Clustering via Parameterized Lloyd's Families
# 978 Learning Beam Search Policies via Imitation Learning
# 979 Benefits of over-parameterization with EM
# 980 Thermostat-assisted continuously-tempered Hamiltonian Monte Carlo for Bayesian learning
# 981 Robust Subspace Approximation in a Stream
# 982 Mean Field for the Stochastic Blockmodel: Optimization Landscape and Convergence Issues
# 983 Analysis of Krylov Subspace Solutions of  Regularized Non-Convex Quadratic Problems
# 984 Autoconj: Recognizing and Exploiting Conjugacy Without a Domain-Specific Language
# 985 DropBlock: A regularization method for convolutional networks
# 986 Forward Modeling for Partial Observation Strategy Games - A StarCraft Defogger
# 987 With Friends Like These, Who Needs Adversaries?
# 988 Decentralize and Randomize: Faster Algorithm for Wasserstein Barycenters
# 989 Joint Autoregressive and Hierarchical Priors for Learned Image Compression
# 990 Learning Temporal Point Processes via Reinforcement Learning
# 991 Bias and Generalization in Deep Generative Models: An Empirical Study
# 992 Fast and Effective Robustness Certification
# 993 Support Recovery for Orthogonal Matching Pursuit: Upper and Lower bounds
# 994 Differentially Private Change-Point Detection
# 995 Multi-value Rule Sets for Interpretable Classification with Feature-Efficient Representations
# 996 Domain Adaptation by Using Causal Inference to Predict Invariant Conditional Distributions
# 997 Smoothed Analysis of Discrete Tensor Decomposition and Assemblies of Neurons
# 998 MixLasso: Generalized Mixed Regression via Convex Atomic-Norm Regularization
# 999 Semidefinite relaxations for certifying robustness to adversarial examples
# 1000 Removing Hidden Confounding by Experimental Grounding
# 1001 Topkapi: Parallel and Fast Sketches for Finding Top-K Frequent Elements
# 1002 Contrastive Learning from Pairwise Measurements
# 1003 Point process latent variable models of larval zebrafish behavior
# 1004 Computationally and statistically efficient learning of causal Bayes nets using path queries
# 1005 Sparse PCA from Sparse Linear Regression
# 1006 Multiple Instance Learning for Efficient Sequential Data Classification on Resource-constrained Devices
# 1007 Transfer of Deep Reactive Policies for MDP Planning
# 1008 The Price of Fair PCA: One Extra dimension
# 1009 GroupReduce: Block-Wise Low-Rank Approximation for Neural Language Model Shrinking

# %%
papers_df = pd.DataFrame(papers)

# %%
papers_df.to_clipboard()

# %%
papers_df['event_type'].value_counts()
# Out:
#  Poster    979
#  Oral       30
# Name: event_type, dtype: int64

# %%
papers_df['paper_authors'].apply(lambda x: len(x)).value_counts()
# Out:
# 3     278
# 4     219
# 2     184
# 5     155
# 6      74
# 7      36
# 1      35
# 8      16
# 10      5
# 9       3
# 12      2
# 0       2
# 11      1
# Name: paper_authors, dtype: int64

# %% [markdown]
# ## Save Metadata to json file

# %%
with open('data/NeurIPS2018/metadata/NeurIPS_Proceedings_Metadata.json','w') as f:
    json.dump(papers, f)
